# %%
def favorite_animal():
  favorite_animal = input("What is your fvorite animal? ")
  print("My favorite animal is also " + favorite_animal + "!")

favorite_animal()
# Out:
# What is your fvorite animal? cow
# My favorite animal is also cow!
