# %%
def get_last_element(lst):
  print("The last element is:", lst[-1])

num_elements = int(input("How many elements are in your list? "))

user_list = []

for i in range(num_elements):
  element = input(f"Enter element #{i +1}: ")
  user_list.append(element)


get_last_element(user_list)
# Out:
# How many elements are in your list? 5
# Enter element #1: Sun
# Enter element #2: Moon
# Enter element #3: Stars
# Enter element #4: Earth
# Enter element #5: Sky
# The last element is: Sky
