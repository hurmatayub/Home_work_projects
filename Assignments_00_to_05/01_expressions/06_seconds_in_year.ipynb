# %%
DAYS_IN_YEARS = 365
HOURS_IN_DAYS = 24
MINUTES_IN_HOURS = 60
SECONDS_IN_MINUTES = 60

def seconds_in_years():
    seconds_in_years = DAYS_IN_YEARS * HOURS_IN_DAYS * MINUTES_IN_HOURS * SECONDS_IN_MINUTES
    print(f"There are {seconds_in_years} seconds in years!")

seconds_in_years()
# Out:
# There are 31536000 seconds in years!
