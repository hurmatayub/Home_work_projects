# %%
def mad_libs():

  SENTENCE_START = "Panaversity is fun. I learned to program and used Python to make my "

  adjective = input("Please type an adjective and press enter. ")
  noun = input("Please type a noun and press enter. ")
  verb = input("Please type a verb and press enter. ")

  print(f"{SENTENCE_START} {adjective} {noun} {verb}!")

mad_libs()
# Out:
# Please type an adjective and press enter. easy
# Please type a noun and press enter. new
# Please type a verb and press enter. work
# Panaversity is fun. I learned to program and used Python to make my  easy new work!
